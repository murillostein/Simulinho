# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np

# %%
# Devido o Plotly estar sendo utilizado no Google Collab, precisaremos definir
# a função abaixo e chamá-la sempre que quisermos exibir um gráfico

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
            },
          });
        </script>
        '''))

# %%
data = pd.read_csv('simulin.csv')
gabarito_ing = pd.read_csv('simulinho_gabarito_ing.csv').T.rename(columns={0:'gabarito_ing'})
gabarito_esp = pd.read_csv('simulinho_gabarito_esp.csv').T.rename(columns={0:'gabarito_esp'})

# %%
materias = pd.DataFrame({
    'questao': [f'questao_{i}' for i in range(1,11)],
    'materia': ['estrangeira']*4 + ['matemática']*3 + ['português']*3
})
materias = materias.set_index(materias['questao']).drop(columns=['questao'])

# %%
materias
# Out:
#                 materia
# questao
# questao_1   estrangeira
# questao_2   estrangeira
# questao_3   estrangeira
# questao_4   estrangeira
# questao_5    matemática
# questao_6    matemática
# questao_7    matemática
# questao_8     português
# questao_9     português
# questao_10    português

# %%
data
# Out:
#        nome             cpf lingua questao_1 questao_2 questao_3 questao_4  \
# 0    Fulano  123.456.789-10    ing         d         e         e         d
# 1  Beltrano  111.222.333-45    ing         d         d         c         e
# 2   Ciclano  999.888.777.65    esp         c         c         d         a
# 3     Pedro  111.111.111-11    ing         a         b         c         d
# 4      Rafa  222.222.222-22    ing         e         d         c         b
# 5      Luli  333.333.333-33    ing         a         c         e         b
#
#   questao_5 questao_6 questao_7 questao_8 questao_9 questao_10
# 0         e         e         d         d         a          b
# 1         d         a         a         c         c          d
# 2         c         d         e         e         a          c
# 3         e         a         b         c         d          e
# 4         a         e         d         c         b          a
# 5         d         a         c         e         d          b

# %%
# junta os dois gabaritos em um mesmo DF pra ficar mais fácil de usar depois
gabarito = gabarito_ing.join(gabarito_esp)

# %%
gabarito
# Out:
#            gabarito_ing gabarito_esp
# questao_1             d            a
# questao_2             e            c
# questao_3             e            b
# questao_4             d            c
# questao_5             e            e
# questao_6             e            e
# questao_7             a            a
# questao_8             e            e
# questao_9             b            b
# questao_10            b            b

# %%
# quebra as respostas para se ter uma resposta por pessoa por linha:
# pd.melt faz exatamente isso. as id_vars são as variáveis de identificação, que não devem ser quebradas por linha
data = pd.melt(data, id_vars=['nome', 'cpf', 'lingua'], var_name='questao', value_name='resposta')

# %%
data
# Out:
#         nome             cpf lingua     questao resposta
# 0     Fulano  123.456.789-10    ing   questao_1        d
# 1   Beltrano  111.222.333-45    ing   questao_1        d
# 2    Ciclano  999.888.777.65    esp   questao_1        c
# 3      Pedro  111.111.111-11    ing   questao_1        a
# 4       Rafa  222.222.222-22    ing   questao_1        e
# 5       Luli  333.333.333-33    ing   questao_1        a
# 6     Fulano  123.456.789-10    ing   questao_2        e
# 7   Beltrano  111.222.333-45    ing   questao_2        d
# 8    Ciclano  999.888.777.65    esp   questao_2        c
# 9      Pedro  111.111.111-11    ing   questao_2        b
# 10      Rafa  222.222.222-22    ing   questao_2        d
# 11      Luli  333.333.333-33    ing   questao_2        c
# 12    Fulano  123.456.789-10    ing   questao_3        e
# 13  Beltrano  111.222.333-45    ing   questao_3        c
# 14   Ciclano  999.888.777.65    esp   questao_3        d
# 15     Pedro  111.111.111-11    ing   questao_3        c
# 16      Rafa  222.222.222-22    ing   questao_3        c
# 17      Luli  333.333.333-33    ing   questao_3        e
# 18    Fulano  123.456.789-10    ing   questao_4        d
# 19  Beltrano  111.222.333-45    ing   questao_4        e
# 20   Ciclano  999.888.777.65    esp   questao_4        a
# 21     Pedro  111.111.111-11    ing   questao_4        d
# 22      Rafa  222.222.222-22    ing   questao_4        b
# 23      Luli  333.333.333-33    ing   questao_4        b
# 24    Fulano  123.456.789-10    ing   questao_5        e
# 25  Beltrano  111.222.333-45    ing   questao_5        d
# 26   Ciclano  999.888.777.65    esp   questao_5        c
# 27     Pedro  111.111.111-11    ing   questao_5        e
# 28      Rafa  222.222.222-22    ing   questao_5        a
# 29      Luli  333.333.333-33    ing   questao_5        d
# 30    Fulano  123.456.789-10    ing   questao_6        e
# 31  Beltrano  111.222.333-45    ing   questao_6        a
# 32   Ciclano  999.888.777.65    esp   questao_6        d
# 33     Pedro  111.111.111-11    ing   questao_6        a
# 34      Rafa  222.222.222-22    ing   questao_6        e
# 35      Luli  333.333.333-33    ing   questao_6        a
# 36    Fulano  123.456.789-10    ing   questao_7        d
# 37  Beltrano  111.222.333-45    ing   questao_7        a
# 38   Ciclano  999.888.777.65    esp   questao_7        e
# 39     Pedro  111.111.111-11    ing   questao_7        b
# 40      Rafa  222.222.222-22    ing   questao_7        d
# 41      Luli  333.333.333-33    ing   questao_7        c
# 42    Fulano  123.456.789-10    ing   questao_8        d
# 43  Beltrano  111.222.333-45    ing   questao_8        c
# 44   Ciclano  999.888.777.65    esp   questao_8        e
# 45     Pedro  111.111.111-11    ing   questao_8        c
# 46      Rafa  222.222.222-22    ing   questao_8        c
# 47      Luli  333.333.333-33    ing   questao_8        e
# 48    Fulano  123.456.789-10    ing   questao_9        a
# 49  Beltrano  111.222.333-45    ing   questao_9        c
# 50   Ciclano  999.888.777.65    esp   questao_9        a
# 51     Pedro  111.111.111-11    ing   questao_9        d
# 52      Rafa  222.222.222-22    ing   questao_9        b
# 53      Luli  333.333.333-33    ing   questao_9        d
# 54    Fulano  123.456.789-10    ing  questao_10        b
# 55  Beltrano  111.222.333-45    ing  questao_10        d
# 56   Ciclano  999.888.777.65    esp  questao_10        c
# 57     Pedro  111.111.111-11    ing  questao_10        e
# 58      Rafa  222.222.222-22    ing  questao_10        a
# 59      Luli  333.333.333-33    ing  questao_10        b

# %%
# juntamos gabarito e respostas em um só DF
# com pd.DataFrame.join, fazemos uma mescla do DF com as respostas e do DF com os gabaritos
# o argumento 'on' nos permite escolher como fazer essa mescla
# nesse caso, fazemos a mescla na coluna 'questao' do DF de respostas,
#   assim, ele pega a linha do DF de gabarito de acordo com o valor da coluna 'questao'
data = data.join(gabarito, on='questao')

# %%
data
# Out:
#         nome             cpf lingua     questao resposta gabarito_ing  \
# 0     Fulano  123.456.789-10    ing   questao_1        d            d
# 1   Beltrano  111.222.333-45    ing   questao_1        d            d
# 2    Ciclano  999.888.777.65    esp   questao_1        c            d
# 3      Pedro  111.111.111-11    ing   questao_1        a            d
# 4       Rafa  222.222.222-22    ing   questao_1        e            d
# 5       Luli  333.333.333-33    ing   questao_1        a            d
# 6     Fulano  123.456.789-10    ing   questao_2        e            e
# 7   Beltrano  111.222.333-45    ing   questao_2        d            e
# 8    Ciclano  999.888.777.65    esp   questao_2        c            e
# 9      Pedro  111.111.111-11    ing   questao_2        b            e
# 10      Rafa  222.222.222-22    ing   questao_2        d            e
# 11      Luli  333.333.333-33    ing   questao_2        c            e
# 12    Fulano  123.456.789-10    ing   questao_3        e            e
# 13  Beltrano  111.222.333-45    ing   questao_3        c            e
# 14   Ciclano  999.888.777.65    esp   questao_3        d            e
# 15     Pedro  111.111.111-11    ing   questao_3        c            e
# 16      Rafa  222.222.222-22    ing   questao_3        c            e
# 17      Luli  333.333.333-33    ing   questao_3        e            e
# 18    Fulano  123.456.789-10    ing   questao_4        d            d
# 19  Beltrano  111.222.333-45    ing   questao_4        e            d
# 20   Ciclano  999.888.777.65    esp   questao_4        a            d
# 21     Pedro  111.111.111-11    ing   questao_4        d            d
# 22      Rafa  222.222.222-22    ing   questao_4        b            d
# 23      Luli  333.333.333-33    ing   questao_4        b            d
# 24    Fulano  123.456.789-10    ing   questao_5        e            e
# 25  Beltrano  111.222.333-45    ing   questao_5        d            e
# 26   Ciclano  999.888.777.65    esp   questao_5        c            e
# 27     Pedro  111.111.111-11    ing   questao_5        e            e
# 28      Rafa  222.222.222-22    ing   questao_5        a            e
# 29      Luli  333.333.333-33    ing   questao_5        d            e
# 30    Fulano  123.456.789-10    ing   questao_6        e            e
# 31  Beltrano  111.222.333-45    ing   questao_6        a            e
# 32   Ciclano  999.888.777.65    esp   questao_6        d            e
# 33     Pedro  111.111.111-11    ing   questao_6        a            e
# 34      Rafa  222.222.222-22    ing   questao_6        e            e
# 35      Luli  333.333.333-33    ing   questao_6        a            e
# 36    Fulano  123.456.789-10    ing   questao_7        d            a
# 37  Beltrano  111.222.333-45    ing   questao_7        a            a
# 38   Ciclano  999.888.777.65    esp   questao_7        e            a
# 39     Pedro  111.111.111-11    ing   questao_7        b            a
# 40      Rafa  222.222.222-22    ing   questao_7        d            a
# 41      Luli  333.333.333-33    ing   questao_7        c            a
# 42    Fulano  123.456.789-10    ing   questao_8        d            e
# 43  Beltrano  111.222.333-45    ing   questao_8        c            e
# 44   Ciclano  999.888.777.65    esp   questao_8        e            e
# 45     Pedro  111.111.111-11    ing   questao_8        c            e
# 46      Rafa  222.222.222-22    ing   questao_8        c            e
# 47      Luli  333.333.333-33    ing   questao_8        e            e
# 48    Fulano  123.456.789-10    ing   questao_9        a            b
# 49  Beltrano  111.222.333-45    ing   questao_9        c            b
# 50   Ciclano  999.888.777.65    esp   questao_9        a            b
# 51     Pedro  111.111.111-11    ing   questao_9        d            b
# 52      Rafa  222.222.222-22    ing   questao_9        b            b
# 53      Luli  333.333.333-33    ing   questao_9        d            b
# 54    Fulano  123.456.789-10    ing  questao_10        b            b
# 55  Beltrano  111.222.333-45    ing  questao_10        d            b
# 56   Ciclano  999.888.777.65    esp  questao_10        c            b
# 57     Pedro  111.111.111-11    ing  questao_10        e            b
# 58      Rafa  222.222.222-22    ing  questao_10        a            b
# 59      Luli  333.333.333-33    ing  questao_10        b            b
#
#    gabarito_esp
# 0             a
# 1             a
# 2             a
# 3             a
# 4             a
# 5             a
# 6             c
# 7             c
# 8             c
# 9             c
# 10            c
# 11            c
# 12            b
# 13            b
# 14            b
# 15            b
# 16            b
# 17            b
# 18            c
# 19            c
# 20            c
# 21            c
# 22            c
# 23            c
# 24            e
# 25            e
# 26            e
# 27            e
# 28            e
# 29            e
# 30            e
# 31            e
# 32            e
# 33            e
# 34            e
# 35            e
# 36            a
# 37            a
# 38            a
# 39            a
# 40            a
# 41            a
# 42            e
# 43            e
# 44            e
# 45            e
# 46            e
# 47            e
# 48            b
# 49            b
# 50            b
# 51            b
# 52            b
# 53            b
# 54            b
# 55            b
# 56            b
# 57            b
# 58            b
# 59            b

# %%
# funcao que retorna o gabarito de acordo com a língua escolhida
def gabarito(row):
  return row['gabarito_'+row['lingua']]

# %%
# aplica a função 'gabarito' a cada linha do DF de dados
data['gabarito'] = data.apply(gabarito, axis=1)
# agora temos uma coluna com o gabarito que leva em conta a língua escolhida

# a correção (acerto ou erro) nada mais é que a comparação entre a resposta e o gabarito
data['correcao'] = data['resposta'] == data['gabarito']

# %%
# remove as colunas de gabaritos esp e ing
data = data.drop(columns=['gabarito_esp', 'gabarito_ing'])

# %%
data
# Out:
#         nome             cpf lingua     questao resposta gabarito  correcao
# 0     Fulano  123.456.789-10    ing   questao_1        d        d      True
# 1   Beltrano  111.222.333-45    ing   questao_1        d        d      True
# 2    Ciclano  999.888.777.65    esp   questao_1        c        a     False
# 3      Pedro  111.111.111-11    ing   questao_1        a        d     False
# 4       Rafa  222.222.222-22    ing   questao_1        e        d     False
# 5       Luli  333.333.333-33    ing   questao_1        a        d     False
# 6     Fulano  123.456.789-10    ing   questao_2        e        e      True
# 7   Beltrano  111.222.333-45    ing   questao_2        d        e     False
# 8    Ciclano  999.888.777.65    esp   questao_2        c        c      True
# 9      Pedro  111.111.111-11    ing   questao_2        b        e     False
# 10      Rafa  222.222.222-22    ing   questao_2        d        e     False
# 11      Luli  333.333.333-33    ing   questao_2        c        e     False
# 12    Fulano  123.456.789-10    ing   questao_3        e        e      True
# 13  Beltrano  111.222.333-45    ing   questao_3        c        e     False
# 14   Ciclano  999.888.777.65    esp   questao_3        d        b     False
# 15     Pedro  111.111.111-11    ing   questao_3        c        e     False
# 16      Rafa  222.222.222-22    ing   questao_3        c        e     False
# 17      Luli  333.333.333-33    ing   questao_3        e        e      True
# 18    Fulano  123.456.789-10    ing   questao_4        d        d      True
# 19  Beltrano  111.222.333-45    ing   questao_4        e        d     False
# 20   Ciclano  999.888.777.65    esp   questao_4        a        c     False
# 21     Pedro  111.111.111-11    ing   questao_4        d        d      True
# 22      Rafa  222.222.222-22    ing   questao_4        b        d     False
# 23      Luli  333.333.333-33    ing   questao_4        b        d     False
# 24    Fulano  123.456.789-10    ing   questao_5        e        e      True
# 25  Beltrano  111.222.333-45    ing   questao_5        d        e     False
# 26   Ciclano  999.888.777.65    esp   questao_5        c        e     False
# 27     Pedro  111.111.111-11    ing   questao_5        e        e      True
# 28      Rafa  222.222.222-22    ing   questao_5        a        e     False
# 29      Luli  333.333.333-33    ing   questao_5        d        e     False
# 30    Fulano  123.456.789-10    ing   questao_6        e        e      True
# 31  Beltrano  111.222.333-45    ing   questao_6        a        e     False
# 32   Ciclano  999.888.777.65    esp   questao_6        d        e     False
# 33     Pedro  111.111.111-11    ing   questao_6        a        e     False
# 34      Rafa  222.222.222-22    ing   questao_6        e        e      True
# 35      Luli  333.333.333-33    ing   questao_6        a        e     False
# 36    Fulano  123.456.789-10    ing   questao_7        d        a     False
# 37  Beltrano  111.222.333-45    ing   questao_7        a        a      True
# 38   Ciclano  999.888.777.65    esp   questao_7        e        a     False
# 39     Pedro  111.111.111-11    ing   questao_7        b        a     False
# 40      Rafa  222.222.222-22    ing   questao_7        d        a     False
# 41      Luli  333.333.333-33    ing   questao_7        c        a     False
# 42    Fulano  123.456.789-10    ing   questao_8        d        e     False
# 43  Beltrano  111.222.333-45    ing   questao_8        c        e     False
# 44   Ciclano  999.888.777.65    esp   questao_8        e        e      True
# 45     Pedro  111.111.111-11    ing   questao_8        c        e     False
# 46      Rafa  222.222.222-22    ing   questao_8        c        e     False
# 47      Luli  333.333.333-33    ing   questao_8        e        e      True
# 48    Fulano  123.456.789-10    ing   questao_9        a        b     False
# 49  Beltrano  111.222.333-45    ing   questao_9        c        b     False
# 50   Ciclano  999.888.777.65    esp   questao_9        a        b     False
# 51     Pedro  111.111.111-11    ing   questao_9        d        b     False
# 52      Rafa  222.222.222-22    ing   questao_9        b        b      True
# 53      Luli  333.333.333-33    ing   questao_9        d        b     False
# 54    Fulano  123.456.789-10    ing  questao_10        b        b      True
# 55  Beltrano  111.222.333-45    ing  questao_10        d        b     False
# 56   Ciclano  999.888.777.65    esp  questao_10        c        b     False
# 57     Pedro  111.111.111-11    ing  questao_10        e        b     False
# 58      Rafa  222.222.222-22    ing  questao_10        a        b     False
# 59      Luli  333.333.333-33    ing  questao_10        b        b      True

# %%
# funcao que retorna o gabarito de acordo com a língua escolhida
def estrangeiras(row):
  if row['lingua'] == 'ing' and row['materia'] == 'estrangeira':
    return 'inglês'
  elif row['lingua'] == 'esp' and row['materia'] == 'estrangeira':
    return 'espanhol'
  else:
    return row['materia']

# %%
data = data.join(materias, on='questao')

# %%
data['materia'] = data.apply(estrangeiras, axis=1)

# %%
data
# Out:
#         nome             cpf lingua     questao resposta gabarito  correcao  \
# 0     Fulano  123.456.789-10    ing   questao_1        d        d      True
# 1   Beltrano  111.222.333-45    ing   questao_1        d        d      True
# 2    Ciclano  999.888.777.65    esp   questao_1        c        a     False
# 3      Pedro  111.111.111-11    ing   questao_1        a        d     False
# 4       Rafa  222.222.222-22    ing   questao_1        e        d     False
# 5       Luli  333.333.333-33    ing   questao_1        a        d     False
# 6     Fulano  123.456.789-10    ing   questao_2        e        e      True
# 7   Beltrano  111.222.333-45    ing   questao_2        d        e     False
# 8    Ciclano  999.888.777.65    esp   questao_2        c        c      True
# 9      Pedro  111.111.111-11    ing   questao_2        b        e     False
# 10      Rafa  222.222.222-22    ing   questao_2        d        e     False
# 11      Luli  333.333.333-33    ing   questao_2        c        e     False
# 12    Fulano  123.456.789-10    ing   questao_3        e        e      True
# 13  Beltrano  111.222.333-45    ing   questao_3        c        e     False
# 14   Ciclano  999.888.777.65    esp   questao_3        d        b     False
# 15     Pedro  111.111.111-11    ing   questao_3        c        e     False
# 16      Rafa  222.222.222-22    ing   questao_3        c        e     False
# 17      Luli  333.333.333-33    ing   questao_3        e        e      True
# 18    Fulano  123.456.789-10    ing   questao_4        d        d      True
# 19  Beltrano  111.222.333-45    ing   questao_4        e        d     False
# 20   Ciclano  999.888.777.65    esp   questao_4        a        c     False
# 21     Pedro  111.111.111-11    ing   questao_4        d        d      True
# 22      Rafa  222.222.222-22    ing   questao_4        b        d     False
# 23      Luli  333.333.333-33    ing   questao_4        b        d     False
# 24    Fulano  123.456.789-10    ing   questao_5        e        e      True
# 25  Beltrano  111.222.333-45    ing   questao_5        d        e     False
# 26   Ciclano  999.888.777.65    esp   questao_5        c        e     False
# 27     Pedro  111.111.111-11    ing   questao_5        e        e      True
# 28      Rafa  222.222.222-22    ing   questao_5        a        e     False
# 29      Luli  333.333.333-33    ing   questao_5        d        e     False
# 30    Fulano  123.456.789-10    ing   questao_6        e        e      True
# 31  Beltrano  111.222.333-45    ing   questao_6        a        e     False
# 32   Ciclano  999.888.777.65    esp   questao_6        d        e     False
# 33     Pedro  111.111.111-11    ing   questao_6        a        e     False
# 34      Rafa  222.222.222-22    ing   questao_6        e        e      True
# 35      Luli  333.333.333-33    ing   questao_6        a        e     False
# 36    Fulano  123.456.789-10    ing   questao_7        d        a     False
# 37  Beltrano  111.222.333-45    ing   questao_7        a        a      True
# 38   Ciclano  999.888.777.65    esp   questao_7        e        a     False
# 39     Pedro  111.111.111-11    ing   questao_7        b        a     False
# 40      Rafa  222.222.222-22    ing   questao_7        d        a     False
# 41      Luli  333.333.333-33    ing   questao_7        c        a     False
# 42    Fulano  123.456.789-10    ing   questao_8        d        e     False
# 43  Beltrano  111.222.333-45    ing   questao_8        c        e     False
# 44   Ciclano  999.888.777.65    esp   questao_8        e        e      True
# 45     Pedro  111.111.111-11    ing   questao_8        c        e     False
# 46      Rafa  222.222.222-22    ing   questao_8        c        e     False
# 47      Luli  333.333.333-33    ing   questao_8        e        e      True
# 48    Fulano  123.456.789-10    ing   questao_9        a        b     False
# 49  Beltrano  111.222.333-45    ing   questao_9        c        b     False
# 50   Ciclano  999.888.777.65    esp   questao_9        a        b     False
# 51     Pedro  111.111.111-11    ing   questao_9        d        b     False
# 52      Rafa  222.222.222-22    ing   questao_9        b        b      True
# 53      Luli  333.333.333-33    ing   questao_9        d        b     False
# 54    Fulano  123.456.789-10    ing  questao_10        b        b      True
# 55  Beltrano  111.222.333-45    ing  questao_10        d        b     False
# 56   Ciclano  999.888.777.65    esp  questao_10        c        b     False
# 57     Pedro  111.111.111-11    ing  questao_10        e        b     False
# 58      Rafa  222.222.222-22    ing  questao_10        a        b     False
# 59      Luli  333.333.333-33    ing  questao_10        b        b      True
#
#        materia
# 0       inglês
# 1       inglês
# 2     espanhol
# 3       inglês
# 4       inglês
# 5       inglês
# 6       inglês
# 7       inglês
# 8     espanhol
# 9       inglês
# 10      inglês
# 11      inglês
# 12      inglês
# 13      inglês
# 14    espanhol
# 15      inglês
# 16      inglês
# 17      inglês
# 18      inglês
# 19      inglês
# 20    espanhol
# 21      inglês
# 22      inglês
# 23      inglês
# 24  matemática
# 25  matemática
# 26  matemática
# 27  matemática
# 28  matemática
# 29  matemática
# 30  matemática
# 31  matemática
# 32  matemática
# 33  matemática
# 34  matemática
# 35  matemática
# 36  matemática
# 37  matemática
# 38  matemática
# 39  matemática
# 40  matemática
# 41  matemática
# 42   português
# 43   português
# 44   português
# 45   português
# 46   português
# 47   português
# 48   português
# 49   português
# 50   português
# 51   português
# 52   português
# 53   português
# 54   português
# 55   português
# 56   português
# 57   português
# 58   português
# 59   português

# %%
media_global = data['correcao'].mean()

# %%
media_global
# Out:
# 0.3

# %%
# usando a função pd.DataFrame.groupby, agrupamos os valores iguais de uma coluna
#   e tiramos uma estatística
# nesse caso, agrupamos por nome e tiramos a média,
#   obtendo assim a média de acerto de cada pessoa (cada nome)
media_total_por_pessoa = data.groupby(['nome']).mean()

# %%
media_total_por_pessoa
# Out:
#           correcao
# nome
# Beltrano       0.2
# Ciclano        0.2
# Fulano         0.7
# Luli           0.3
# Pedro          0.2
# Rafa           0.2

# %%
# aqui tiramos a média de acerto por questão por prova (ing ou esp)
media_acerto_questao = data.groupby(['lingua', 'questao']).mean()

# %%
media_acerto_questao
# Out:
#                    correcao
# lingua questao
# esp    questao_1        0.0
#        questao_10       0.0
#        questao_2        1.0
#        questao_3        0.0
#        questao_4        0.0
#        questao_5        0.0
#        questao_6        0.0
#        questao_7        0.0
#        questao_8        1.0
#        questao_9        0.0
# ing    questao_1        0.4
#        questao_10       0.4
#        questao_2        0.2
#        questao_3        0.4
#        questao_4        0.4
#        questao_5        0.4
#        questao_6        0.4
#        questao_7        0.2
#        questao_8        0.2
#        questao_9        0.2

# %%
media_por_materia = data.groupby(['materia']).mean()

# %%
media_por_materia
# Out:
#             correcao
# materia
# espanhol    0.250000
# inglês      0.350000
# matemática  0.277778
# português   0.277778

# %%
media_por_pessoa_por_materia = data.groupby(['nome','materia']).mean().unstack()['correcao']

# %%
media_por_pessoa_por_materia
# Out:
# materia   espanhol  inglês  matemática  português
# nome
# Beltrano       NaN    0.25    0.333333   0.000000
# Ciclano       0.25     NaN    0.000000   0.333333
# Fulano         NaN    1.00    0.666667   0.333333
# Luli           NaN    0.25    0.000000   0.666667
# Pedro          NaN    0.25    0.333333   0.000000
# Rafa           NaN    0.00    0.333333   0.333333

# %%
quartis = media_por_pessoa_por_materia.quantile([0.25, 0.5, 0.75])
quartis
# Out:
# materia  espanhol  inglês  matemática  português
# 0.25         0.25    0.25    0.083333   0.083333
# 0.50         0.25    0.25    0.333333   0.333333
# 0.75         0.25    0.25    0.333333   0.333333

# %%
correlacao_ing = media_por_pessoa_por_materia.drop(columns=['espanhol']).dropna().corr()
correlacao_esp = media_por_pessoa_por_materia.drop(columns=['inglês']).dropna().corr()

# %% [markdown]
# correlacao_ing

# %% [markdown]
# ## Corretor redação

# %%
df_redacao = pd.read_excel("Gabarito/redacao.xlsx")
df_redacao
# Out:
#        nome  Norma culta comentarios  Adequação ao tema comentarios.1  \
# 0    Fulano            0         bom                 40           bom
# 1  Beltrano          160   muito bom                 80     muito bom
# 2   Ciclano           40       otimo                 40         otimo
# 3     Pedro           80      melhor                120        melhor
# 4      Rafa           80        pior                 40          pior
# 5      Luli          160       igual                120         igual
#
#    Argumentação comentarios.2  Coesão comentarios.3  Proposta de intervenção  \
# 0            80           bom     120           bom                      160
# 1            40     muito bom     160     muito bom                      160
# 2            40         otimo      40         otimo                       40
# 3           120        melhor     160        melhor                      200
# 4           160          pior      40          pior                       40
# 5            80         igual      40         igual                        0
#
#   comentarios.4  Nota   comentarios.5
# 0           bom   400             bom
# 1     muito bom   600  melhorar letra
# 2         otimo   200          piorou
# 3        melhor   680        melhorou
# 4          pior   360        ilegivel
# 5         igual   400     muito curto

# %% [markdown]
# # Métricas

# %% [markdown]
# ## Alunos

# %% [markdown]
# ### Questões objetivas

# %%
# calcula o total de questões certas por máteria, quantas questões tinham por matéria, e média por matéria

# agg permite agregar multiplas funções ao groupby
acertos_aluno = data.groupby(['nome','materia'])['correcao'].agg(['sum','count','mean'])
acertos_aluno = acertos_aluno.rename(columns={"sum": "Total Acertos", "mean": "Média Individual", 'count': "Total questoes"})
acertos_aluno
# Out:
#                      Total Acertos  Total questoes  Média Individual
# nome     materia
# Beltrano inglês                  1               4          0.250000
#          matemática              1               3          0.333333
#          português               0               3          0.000000
# Ciclano  espanhol                1               4          0.250000
#          matemática              0               3          0.000000
#          português               1               3          0.333333
# Fulano   inglês                  4               4          1.000000
#          matemática              2               3          0.666667
#          português               1               3          0.333333
# Luli     inglês                  1               4          0.250000
#          matemática              0               3          0.000000
#          português               2               3          0.666667
# Pedro    inglês                  1               4          0.250000
#          matemática              1               3          0.333333
#          português               0               3          0.000000
# Rafa     inglês                  0               4          0.000000
#          matemática              1               3          0.333333
#          português               1               3          0.333333

# %%
# comparar a média de acerto das questões dos alunos com a turma geral

# media geral do einstein
media_acerto_materia = data.groupby('materia').mean()

media_acerto_materia = media_acerto_materia.rename(columns={"correcao": "Media Geral"})

# adicionando a media geral aos dados individuais
acertos_aluno = acertos_aluno.join(media_acerto_materia, on='materia')
acertos_aluno
# Out:
#                      Total Acertos  Total questoes  Média Individual  \
# nome     materia
# Beltrano inglês                  1               4          0.250000
#          matemática              1               3          0.333333
#          português               0               3          0.000000
# Ciclano  espanhol                1               4          0.250000
#          matemática              0               3          0.000000
#          português               1               3          0.333333
# Fulano   inglês                  4               4          1.000000
#          matemática              2               3          0.666667
#          português               1               3          0.333333
# Luli     inglês                  1               4          0.250000
#          matemática              0               3          0.000000
#          português               2               3          0.666667
# Pedro    inglês                  1               4          0.250000
#          matemática              1               3          0.333333
#          português               0               3          0.000000
# Rafa     inglês                  0               4          0.000000
#          matemática              1               3          0.333333
#          português               1               3          0.333333
#
#                      Media Geral
# nome     materia
# Beltrano inglês         0.350000
#          matemática     0.277778
#          português      0.277778
# Ciclano  espanhol       0.250000
#          matemática     0.277778
#          português      0.277778
# Fulano   inglês         0.350000
#          matemática     0.277778
#          português      0.277778
# Luli     inglês         0.350000
#          matemática     0.277778
#          português      0.277778
# Pedro    inglês         0.350000
#          matemática     0.277778
#          português      0.277778
# Rafa     inglês         0.350000
#          matemática     0.277778
#          português      0.277778

# %%
acertos_aluno_total = data.groupby(['nome']).sum()
acertos_aluno_total
# Out:
#           correcao
# nome
# Beltrano         2
# Ciclano          2
# Fulano           7
# Luli             3
# Pedro            2
# Rafa             2

# %% [markdown]
# ### Redação

# %%
# calcula a nota individual da redação + comentarios

# pontuacao_redacao = df_redacao
# pontuacao_redacao['nota'] = pontuacao_redacao[['Norma culta','Adequação ao tema','Argumentação','Coesão', 'Proposta de intervenção'
# ]].sum(axis=1)

# %%
#pontuacao_redacao

# %% [markdown]
# ### Pontuação Total

# %%
# juntando a pontuação das questões objetivas com a nota da redação
pontuacao_total = df_redacao['Nota']
pontuacao_total = pontuacao_redacao.join(acertos_aluno_total, on='nome')

pontuacao_total = pontuacao_total.drop(labels=['Norma culta','Adequação ao tema','Argumentação','Coesão', 'Proposta de intervenção'
,'comentarios', 'comentarios.1','comentarios.2','comentarios.3','comentarios.4', 'comentarios.5', 'nota'], axis =1)

pontuacao_total
# Out:
#        nome  Nota  correcao
# 0    Fulano   400         7
# 1  Beltrano   600         2
# 2   Ciclano   200         2
# 3     Pedro   680         2
# 4      Rafa   360         2
# 5      Luli   400         3

# %%
# pega a colocação de cada aluno com base no nº de acertos

# verificar depois a info a seguir
# se o simulinho for que nem enem, as questões tambem tem peso igual o da redacao, ou seja, a nota das questoes objetivas vai
# de 0 à 500, logo, devemos multiplicar a coluna correçaõ por 10

pontuacao_total['correcao'] *= 10
pontuacao_total
# Out:
#        nome  Nota  correcao
# 0    Fulano   400        70
# 1  Beltrano   600        20
# 2   Ciclano   200        20
# 3     Pedro   680        20
# 4      Rafa   360        20
# 5      Luli   400        30

# %%
# a pontuacao total é a média entre as questoes objetivas e a nota da redacao
pontuacao_total['total'] = pontuacao_total[['Nota','correcao']].sum(axis=1)
pontuacao_total
# Out:
#        nome  Nota  correcao  total
# 0    Fulano   400        70    470
# 1  Beltrano   600        20    620
# 2   Ciclano   200        20    220
# 3     Pedro   680        20    700
# 4      Rafa   360        20    380
# 5      Luli   400        30    430

# %%
# porcentagem de acerto da prova
# a % é igual à nota geral divida por 1500 (que é a nota máxima)
# nesse dataset de teste a pontuação máxima seria 1090 (redaçaõ + 9 questões)
pontuacao_total['% de acerto'] = pontuacao_total['total'] / 1500
pontuacao_total
# Out:
#        nome  Nota  correcao  total  % de acerto
# 0    Fulano   400        70    470     0.313333
# 1  Beltrano   600        20    620     0.413333
# 2   Ciclano   200        20    220     0.146667
# 3     Pedro   680        20    700     0.466667
# 4      Rafa   360        20    380     0.253333
# 5      Luli   400        30    430     0.286667

# %%
# ver a colocação de cada aluno

colocacao = pontuacao_total.sort_values(by='total', ascending=False)

# como os indices ficam fora de ordem depois de colocar as notas em valor decrescente, é necessário resetar o valor do indices
# de 'colocacao'
colocacao = colocacao.reset_index(drop=True)
colocacao
# Out:
#        nome  Nota  correcao  total  % de acerto
# 0     Pedro   680        20    700     0.466667
# 1  Beltrano   600        20    620     0.413333
# 2    Fulano   400        70    470     0.313333
# 3      Luli   400        30    430     0.286667
# 4      Rafa   360        20    380     0.253333
# 5   Ciclano   200        20    220     0.146667

# %% [markdown]
# ## Docentes

# %%
# total de inscritos

# falta discretizar por dia de prova

total_presentes = data['nome'].nunique()
total_presentes
# Out:
# 6

# %% [markdown]
# ### Objetivas

# %%
# media de acertos em cada questão
media_acerto_questao = data.groupby(['materia', 'questao']).mean()

media_acerto_questao
# Out:
#                        correcao
# materia    questao
# espanhol   questao_1   0.000000
#            questao_2   1.000000
#            questao_3   0.000000
#            questao_4   0.000000
# inglês     questao_1   0.400000
#            questao_2   0.200000
#            questao_3   0.400000
#            questao_4   0.400000
# matemática questao_5   0.333333
#            questao_6   0.333333
#            questao_7   0.166667
# português  questao_10  0.333333
#            questao_8   0.333333
#            questao_9   0.166667

# %%
# questões com mais acertos

# ingles e espanhol podem ter numeros muito diferentes por o total de alunos em cada materia pode ser muito diferente

mais_acertos = data.groupby(['materia', 'questao']).agg(['sum','count','mean'])
mais_acertos = mais_acertos.rename(columns={"sum": "Total Acertos", "mean": "Média", 'count': "Total Alunos"})

##### não consegui fazer um sort_values
mais_acertos
# Out:
#                            correcao
#                       Total Acertos Total Alunos     Média
# materia    questao
# espanhol   questao_1              0            1  0.000000
#            questao_2              1            1  1.000000
#            questao_3              0            1  0.000000
#            questao_4              0            1  0.000000
# inglês     questao_1              2            5  0.400000
#            questao_2              1            5  0.200000
#            questao_3              2            5  0.400000
#            questao_4              2            5  0.400000
# matemática questao_5              2            6  0.333333
#            questao_6              2            6  0.333333
#            questao_7              1            6  0.166667
# português  questao_10             2            6  0.333333
#            questao_8              2            6  0.333333
#            questao_9              1            6  0.166667

# %%
# media total de acertos em toda prova objetiva

media_acertos_obj = data['correcao'].mean()

media_acertos_obj
# Out:
# 0.3

# %%
# porcentagem de acerto geral na prova = total de acertos / total de linhas
porcentagem_acerto_obj = data['correcao'].sum() / data.shape[0]
porcentagem_acerto_obj
# Out:
# 0.3

# %%
# porcentagem acerto em cada materia = media de acerto de cada materia
media_acerto_materia = data.groupby('materia').mean()

media_acerto_materia
# Out:
#             correcao
# materia
# espanhol    0.250000
# inglês      0.350000
# matemática  0.277778
# português   0.277778

# %% [markdown]
# ### Redação

# %%
pontuacao_redacao['nota'] = pontuacao_redacao[['Norma culta','Adequação ao tema','Argumentação','Coesão', 'Proposta de intervenção'
]].sum(axis=1)
pontuacao_redacao
# Out:
#        nome  Norma culta comentarios  Adequação ao tema comentarios.1  \
# 0    Fulano            0         bom                 40           bom
# 1  Beltrano          160   muito bom                 80     muito bom
# 2   Ciclano           40       otimo                 40         otimo
# 3     Pedro           80      melhor                120        melhor
# 4      Rafa           80        pior                 40          pior
# 5      Luli          160       igual                120         igual
#
#    Argumentação comentarios.2  Coesão comentarios.3  Proposta de intervenção  \
# 0            80           bom     120           bom                      160
# 1            40     muito bom     160     muito bom                      160
# 2            40         otimo      40         otimo                       40
# 3           120        melhor     160        melhor                      200
# 4           160          pior      40          pior                       40
# 5            80         igual      40         igual                        0
#
#   comentarios.4  Nota   comentarios.5  nota
# 0           bom   400             bom   400
# 1     muito bom   600  melhorar letra   600
# 2         otimo   200          piorou   200
# 3        melhor   680        melhorou   680
# 4          pior   360        ilegivel   360
# 5         igual   400     muito curto   400

# %%
#Média de pontuação na Redação
media_redacao = pontuacao_redacao[['Norma culta','Adequação ao tema','Argumentação','Coesão', 'Proposta de intervenção'
,'nota']].mean()
media_redacao
# Out:
# Norma culta                 86.666667
# Adequação ao tema           73.333333
# Argumentação                86.666667
# Coesão                      93.333333
# Proposta de intervenção    100.000000
# nota                       440.000000
# dtype: float64

# %%
#Porcentagem de acerto total na Redação

# como a nota maxima para cada criterio é 200, divide-se as notas por 200 para calcular o quantos % os alunos atingiram do valor máximo
porcem_acertos_redacao = df_redacao[['Norma culta','Adequação ao tema','Argumentação','Coesão', 'Proposta de intervenção']]/200

# calcula a media de porcentagem de acerto
porcem_acertos_redacao.mean()
# Out:
# Norma culta                0.433333
# Adequação ao tema          0.366667
# Argumentação               0.433333
# Coesão                     0.466667
# Proposta de intervenção    0.500000
# dtype: float64

# %% [markdown]
# ### Pontuação total

# %%
# a media da pontuação geral é a média entre os acertos de questões objetivas e a média das notas de redação

# assim como em Alunos -> pontuação total, tem que verificar a info a seguir
# como a média de acertos não está no padrão das notas de redação, é necessário multiplicar a média de acertos das questoes 
# objetivas por 1000
media_pontuacao_total = (media_acertos_obj*100 + media_redacao['nota'])/2
media_pontuacao_total
# Out:
# 235.0

# %%
# porcentagem de acertos da prova toda (objetivas + redação)

# %%
# 10 melhores colocados, nota total e % de acertos
# 'colocacao' foi definido na seção de métricas de alunos
top10 = colocacao.head(10)
top10
# Out:
#        nome  Nota  correcao  total  % de acerto
# 0     Pedro   680        20    700     0.466667
# 1  Beltrano   600        20    620     0.413333
# 2    Fulano   400        70    470     0.313333
# 3      Luli   400        30    430     0.286667
# 4      Rafa   360        20    380     0.253333
# 5   Ciclano   200        20    220     0.146667

# %%
# 5 melhores, nota total e % de acertos
top5 = colocacao.head(5)
top5
# Out:
#        nome  Nota  correcao  total  % de acerto
# 0     Pedro   680        20    700     0.466667
# 1  Beltrano   600        20    620     0.413333
# 2    Fulano   400        70    470     0.313333
# 3      Luli   400        30    430     0.286667
# 4      Rafa   360        20    380     0.253333
